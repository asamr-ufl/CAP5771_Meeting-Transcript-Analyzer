# %%
from datasets import load_dataset

dataset = load_dataset("edinburghcstr/ami", "ihm")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/36 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 108502
#     })
#     validation: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 13098
#     })
#     test: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 12643
#     })
# })

# %%
df = dataset["train"].select(range(5000)).to_pandas()
df.head()
# Out:
#   meeting_id                                audio_id  \
# 0    EN2001a  AMI_EN2001a_H04_MEO069_0330297_0330718
# 1    EN2001a  AMI_EN2001a_H00_MEE068_0414915_0415078
# 2    EN2001a  AMI_EN2001a_H03_MEE067_0319290_0319815
# 3    EN2001a  AMI_EN2001a_H04_MEO069_0145515_0146152
# 4    EN2001a  AMI_EN2001a_H03_MEE067_0478127_0478164
#
#                                                 text  \
# 0  IF YOU IF YOU S. S. H. AND THEY HAVE THIS BIG ...
# 1                          I'VE GOTTEN MM HARDLY ANY
# 2  IT'S YEAH I MEAN THE WAVE DATA ARE OBVIOUSLY N...
# 3  YEAH IT'LL IT'LL PLAY THEM IN SOME ORDER IN WH...
# 4                                               YEAH
#
#                                                audio   begin_time  \
# 0  {'bytes': b'RIFF\xb2\x1c\x04\x00WAVEfmt \x12\x...  3302.969971
# 1  {'bytes': b'RIFF\xb2\x97\x01\x00WAVEfmt \x12\x...  4149.149902
# 2  {'bytes': b'RIFF\xb2 \x05\x00WAVEfmt \x12\x00\...  3192.899902
# ...

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 108502
#     })
#     validation: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 13098
#     })
#     test: Dataset({
#         features: ['meeting_id', 'audio_id', 'text', 'audio', 'begin_time', 'end_time', 'microphone_id', 'speaker_id'],
#         num_rows: 12643
#     })
# })

# %%
df.info()


df.describe(include="all")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   meeting_id     5000 non-null   str
#  1   audio_id       5000 non-null   str
#  2   text           5000 non-null   str
#  3   audio          5000 non-null   object
#  4   begin_time     5000 non-null   float32
#  5   end_time       5000 non-null   float32
#  6   microphone_id  5000 non-null   str
#  7   speaker_id     5000 non-null   str
# dtypes: float32(2), object(1), str(5)
# memory usage: 770.1+ KB
#        meeting_id                                audio_id  text  \
# count        5000                                    5000  5000
# unique          4                                    5000  3716
# top       EN2001a  AMI_EN2001a_H04_MEO069_0330297_0330718  YEAH
# freq         1675                                       1   432
# ...
